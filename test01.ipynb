# %%
from sklearn import tree

X = [[0,0], [0,1]]
y = [0,1]

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
clf.predict_proba([[0,0.5]])
# Out:
# array([[1., 0.]])

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %% [markdown]
# ## Exercise: dummy data

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame()
n = 2000 # num data
df['Age'] = [np.random.randint(20,80) for i in range(n)]
df['College Degree?'] = [np.random.choice([0,1]) for i in range(n)]
df['EarningGood'] = [1 if (df['College Degree?'][i]==1 and df['Age'][i] >= 50) else 0 for i in range(n)]

# %%
df
# Out:
#       Age  College Degree?  EarningGood
# 0      54                1            1
# 1      34                1            0
# 2      76                1            1
# 3      45                0            0
# 4      45                1            0
# ...   ...              ...          ...
# 1995   51                0            0
# 1996   56                0            0
# 1997   46                0            0
# 1998   67                1            1
# 1999   65                1            1
#
# [2000 rows x 3 columns]

# %%
x = df.drop(columns=['EarningGood'])
x = np.array(x)
y = df['EarningGood']
y = np.array(y)

# %%
y
# Out:
# array([1, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= 49.5\ngini = 0.385\nsamples = 2000\nvalue = [1480, 520]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 978\nvalue = [978, 0]'),
#  Text(0.6, 0.5, 'x[1] <= 0.5\ngini = 0.5\nsamples = 1022\nvalue = [502, 520]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 502\nvalue = [502, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 520\nvalue = [0, 520]')]

# %%
clf.predict([[500,0]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# ## regeression decision trees

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame()
n = 100 # num data
df['Age'] = [np.random.randint(20,80) for i in range(n)]
df['College Degree?'] = [np.random.choice([0,1]) for i in range(n)]
#df['Y'] = [1 if (df['College Degree?'][i]==1 and df['Age'][i] >= 50) else 0 for i in range(n)]
df['Y'] = [(df['College Degree?'][i]*10 + df['Age'][i])  for i in range(n)]

#df['Y'] = df['Age'].mean()

x = df.drop(columns=['Y'])
x = np.array(x)
y = df['Y']
y = np.array(y)

clf = tree.DecisionTreeRegressor?
clf.fit(x,y)
# Out:
# DecisionTreeRegressor(min_impurity_decrease=0.1)
# Init signature:
# tree.DecisionTreeRegressor(
#     *,
#     criterion='squared_error',
#     splitter='best',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features=None,
#     random_state=None,
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     ccp_alpha=0.0,
# )
# Docstring:
# A decision tree regressor.
#
# Read more in the :ref:`User Guide <tree>`.
#
# Parameters
# ----------
# criterion : {"squared_error", "friedman_mse", "absolute_error",             "poisson"}, default="squared_error"
#     The function to measure the quality of a split. Supported criteria
#     are "squared_error" for the mean squared error, which is equal to
#     variance reduction as feature selection criterion and minimizes the L2
#     loss using the mean of each terminal node, "friedman_mse", which uses
# ...

# %%
clf.predict([[10,2]])
# Out:
# array([32.33333333])

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[0] <= 49.5\nsquared_error = 381.694\nsamples = 100\nvalue = 52.84'),
#  Text(0.26875, 0.75, 'x[0] <= 32.0\nsquared_error = 86.826\nsamples = 48\nvalue = 35.083'),
#  Text(0.1625, 0.5833333333333334, 'x[1] <= 0.5\nsquared_error = 28.522\nsamples = 25\nvalue = 27.72'),
#  Text(0.1, 0.4166666666666667, 'x[0] <= 25.5\nsquared_error = 11.391\nsamples = 19\nvalue = 25.368'),
#  Text(0.05, 0.25, 'x[0] <= 23.5\nsquared_error = 2.44\nsamples = 10\nvalue = 22.6'),
#  Text(0.025, 0.08333333333333333, 'squared_error = 0.776\nsamples = 7\nvalue = 21.714'),
#  Text(0.075, 0.08333333333333333, 'squared_error = 0.222\nsamples = 3\nvalue = 24.667'),
#  Text(0.15, 0.25, 'x[0] <= 28.0\nsquared_error = 3.358\nsamples = 9\nvalue = 28.444'),
#  Text(0.125, 0.08333333333333333, 'squared_error = 0.25\nsamples = 4\nvalue = 26.5'),
#  Text(0.175, 0.08333333333333333, 'squared_error = 0.4\nsamples = 5\nvalue = 30.0'),
# ...
