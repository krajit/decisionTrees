# %%
import numpy as np
import pandas as pd
pd.set_option('display.precision',3)

# %%
df = pd.DataFrame({
    "Likes Popcorn" : [1,1,0,1,0,0],
    "Age": [12, 87, 44, 19, 32, 14],
    "Fav Color": ['B','G','B','R','G','B'],
    "Loves Troll": [1,1,0,0,1,1]
})
df
# Out:
#    Likes Popcorn  Age Fav Color  Loves Troll
# 0              1   12         B            1
# 1              1   87         G            1
# 2              0   44         B            0
# 3              1   19         R            0
# 4              0   32         G            1
# 5              0   14         B            1

# %% [markdown]
# ## Step 1
#
# - log of odd
#
# - convert odds to probability
#
# ![image.png](attachment:31bdfe14-c47d-4934-b350-841e640f9ba0.png)

# %%
## Step 1a

odds = (df['Loves Troll'] == 1).sum()/(df['Loves Troll'] == 0).sum()
odds = np.log(odds)
P = np.exp(odds)/(1 + np.exp(odds))
P
df['pred1'] = P
df
# Out:
#    Likes Popcorn  Age Fav Color  Loves Troll     pred1
# 0              1   12         B            1  0.666667
# 1              1   87         G            1  0.666667
# 2              0   44         B            0  0.666667
# 3              1   19         R            0  0.666667
# 4              0   32         G            1  0.666667
# 5              0   14         B            1  0.666667

# %% [markdown]
# ## Step 2: Calculate residuals
#
# residuals  = observed - prev predictions

# %%
df['res1'] = df['Loves Troll'] - df['pred1']
df
# Out:
#    Likes Popcorn  Age Fav Color  Loves Troll     pred1      res1
# 0              1   12         B            1  0.666667  0.333333
# 1              1   87         G            1  0.666667  0.333333
# 2              0   44         B            0  0.666667 -0.666667
# 3              1   19         R            0  0.666667 -0.666667
# 4              0   32         G            1  0.666667  0.333333
# 5              0   14         B            1  0.666667  0.333333

# %% [markdown]
# ## Step 3:
#
# Create a tree to predict residuals

# %%
df = pd.get_dummies(df)
df
# Out:
#    Likes Popcorn  Age  Loves Troll     pred1      res1  Fav Color_B  \
# 0              1   12            1  0.666667  0.333333         True
# 1              1   87            1  0.666667  0.333333        False
# 2              0   44            0  0.666667 -0.666667         True
# 3              1   19            0  0.666667 -0.666667        False
# 4              0   32            1  0.666667  0.333333        False
# 5              0   14            1  0.666667  0.333333         True
#
#    Fav Color_G  Fav Color_R
# 0        False        False
# 1         True        False
# 2        False        False
# 3        False         True
# 4         True        False
# 5        False        False

# %%
x = np.array(df.drop(columns=['pred1', 'Loves Troll', 'res1']))
y = np.array(df['res1'])

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

t1 = DecisionTreeRegressor(max_depth=2)
t1.fit(x,y)
tree.plot_tree(t1, feature_names=['Likes Popcorn','Age', 'Fav Color_B', 'Fav Color_G', 'Fav Color_R'])
# Out:
# [Text(0.6, 0.8333333333333334, 'Fav Color_R <= 0.5\nsquared_error = 0.222\nsamples = 6\nvalue = 0.0'),
#  Text(0.4, 0.5, 'Age <= 38.0\nsquared_error = 0.16\nsamples = 5\nvalue = 0.133'),
#  Text(0.2, 0.16666666666666666, 'squared_error = 0.0\nsamples = 3\nvalue = 0.333'),
#  Text(0.6, 0.16666666666666666, 'squared_error = 0.25\nsamples = 2\nvalue = -0.167'),
#  Text(0.8, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = -0.667')]

# %%
df['pred_t1'] = t1.predict(x)
df
# Out:
#    Likes Popcorn  Age  Loves Troll  pred1   res1  Fav Color_B  Fav Color_G  \
# 0              1   12            1  0.667  0.333         True        False
# 1              1   87            1  0.667  0.333        False         True
# 2              0   44            0  0.667 -0.667         True        False
# 3              1   19            0  0.667 -0.667        False        False
# 4              0   32            1  0.667  0.333        False         True
# 5              0   14            1  0.667  0.333         True        False
#
#    Fav Color_R  pred_t1
# 0        False    0.333
# 1        False   -0.167
# 2        False   -0.167
# 3         True   -0.667
# 4        False    0.333
# 5        False    0.333

# %%
df.drop(columns='pred_1',inplace=True)
