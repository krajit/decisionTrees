# %% [markdown]
# ## y = 1 if x1 <= x0
#
# ![image.png](attachment:8002e05a-9c0b-4426-88e7-b93dd5313af5.png)

# %%
import pandas as pd
import numpy as np
from sklearn import tree

df = pd.DataFrame()
n = 2000 # num data
df['x1'] = [np.random.randint(0,100) for i in range(n)]
df['x2'] = [np.random.randint(0,100) for i in range(n)]

df['y'] = [1 if (df['x1'][i]  >= df['x2'][i] ) else 0 for i in range(n)]

x = df.drop(columns=['y'])
x = np.array(x)
y = df['y']
y = np.array(y)

import matplotlib.pyplot as plt

plt.plot(x[:, 0][y==0], x[:, 1][y==0], "yo", marker='.')
plt.plot(x[:, 0][y==1], x[:, 1][y==1], "bo", marker='.')
# Out:
# C:\Users\sneh.lata\AppData\Local\Temp\ipykernel_33608\3203542233.py:19: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "yo" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x[:, 0][y==0], x[:, 1][y==0], "yo", marker='.')
# C:\Users\sneh.lata\AppData\Local\Temp\ipykernel_33608\3203542233.py:20: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x[:, 0][y==1], x[:, 1][y==1], "bo", marker='.')
